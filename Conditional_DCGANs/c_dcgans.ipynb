# %%
# !python3 /content/drive/MyDrive/DeepLearning_Project/convolutional_gans.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# Epoch [1/50], BatchStep[100/937], D_Real_loss: 0.1824, D_Fake_loss: 0.4760, G_loss: 3.5516
# Epoch [1/50], BatchStep[200/937], D_Real_loss: 0.6304, D_Fake_loss: 0.4003, G_loss: 2.7707
# Epoch [1/50], BatchStep[300/937], D_Real_loss: 0.6871, D_Fake_loss: 0.3376, G_loss: 2.5000
# Epoch [1/50], BatchStep[400/937], D_Real_loss: 0.4299, D_Fake_loss: 0.0704, G_loss: 3.7602
# ...

# %%
# !zip -r c_dcgan_imgs.zip /content/images-conditional_dcgan
# Out:
#   adding: content/images-conditional_dcgan/ (stored 0%)
#   adding: content/images-conditional_dcgan/7-7200.png (deflated 4%)
#   adding: content/images-conditional_dcgan/29-27200.png (deflated 4%)
#   adding: content/images-conditional_dcgan/11-10800.png (deflated 4%)
#   adding: content/images-conditional_dcgan/5-4800.png (deflated 4%)
#   adding: content/images-conditional_dcgan/36-34400.png (deflated 3%)
#   adding: content/images-conditional_dcgan/17-16400.png (deflated 4%)
#   adding: content/images-conditional_dcgan/17-16000.png (deflated 4%)
#   adding: content/images-conditional_dcgan/43-41200.png (deflated 3%)
#   adding: content/images-conditional_dcgan/43-40400.png (deflated 3%)
#   adding: content/images-conditional_dcgan/14-14000.png (deflated 4%)
#   adding: content/images-conditional_dcgan/19-18000.png (deflated 4%)
#   adding: content/images-conditional_dcgan/31-29200.png (deflated 4%)
#   adding: content/images-conditional_dcgan/5-5200.png (deflated 4%)
# ...
